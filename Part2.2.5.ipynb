# %%
import sys
import time
import numpy as np
import pandas as pd
from gensim.models import KeyedVectors
from sklearn.metrics import accuracy_score
from __future__ import division
from collections import Counter

# %%
wv = KeyedVectors.load('embs_train.kv')

# %%
def sentence_embedding(sentence, word_counts):
    tokens = sentence.split()
    embeddings = []
    for token in tokens:
        if token in wv and word_counts[token] > 1:
            embeddings.append(wv[token])
    if len(embeddings) > 0:
        return np.mean(embeddings, axis=0)
    else:
        return np.zeros(wv.vector_size)

# %%
def read_from(dataframe):
    for i, row in dataframe.iterrows():
        label = 1 if row['Label'] == '+' else -1
        yield (label, row['Review_Embedding'])

# %%
def test(dev_data, model):
    tot, err = 0, 0
    for label, emb in read_from(dev_data):
        err += label * (np.dot(model, emb)) <= 0
    return err / len(dev_data)

# %%
def averaged_perceptron(train_data, dev_data, epochs=10):
    t = time.time()
    best_err = 1.
    avg_model = np.zeros(train_data['Review_Embedding'].iloc[0].shape)  
    model = np.zeros(train_data['Review_Embedding'].iloc[0].shape)  


    word_counts = Counter()
    for review in train_data['Review']:
        word_counts.update(review.split())

    for it in range(1, epochs + 1):
        updates = 0
        for label, emb in read_from(train_data):
            if label * (np.dot(model, emb)) <= 0:
                updates += 1
                model += label * emb
            avg_model += model

        dev_err = test(dev_data, avg_model)
        if dev_err < best_err:
            best_err = dev_err
            best_model = avg_model.copy()  
        print("epoch %d, update %.1f%%, dev %.1f%%" % (it, updates / len(train_data) * 100, dev_err * 100))
    
    avg_model /= (epochs * len(train_data))  
    print("best dev err %.1f%%, time: %.1f secs" % (best_err * 100, time.time() - t))
    
    return best_model

# %%
if __name__ == "__main__":
    train_data = pd.read_csv('C:/3rd term/ML/HW-4/hw4-data/train.txt', sep='\t', header=None, names=['Label', 'Review'])
    dev_data = pd.read_csv('C:/3rd term/ML/HW-4/hw4-data/dev.txt', sep='\t', header=None, names=['Label', 'Review'])
    
    
    word_counts = Counter()
    for review in train_data['Review']:
        word_counts.update(review.split())

    
    train_data['Review_Embedding'] = train_data['Review'].apply(lambda x: sentence_embedding(x, word_counts))
    dev_data['Review_Embedding'] = dev_data['Review'].apply(lambda x: sentence_embedding(x, word_counts))

    best_model = averaged_perceptron(train_data, dev_data, epochs=10)

    
    correct_examples = []
    for index, (label, emb) in enumerate(read_from(dev_data)):
        prediction = np.dot(best_model, emb)
        if (prediction > 0 and label == 1) or (prediction <= 0 and label == -1):
            correct_examples.append((index, prediction))

    
    print(f"Number of correct examples found: {len(correct_examples)}")
    for idx, pred in correct_examples:
        print(f"Example Index: {idx}, Predicted Label: {'+' if pred > 0 else '-'}")
        print(f"Review: {dev_data.iloc[idx]['Review']}")
        print("------------------------------------------------------------")

    
    predicted_labels = []
    for _, emb in read_from(dev_data):
        prediction = np.dot(best_model, emb)
        if prediction > 0:
            predicted_labels.append('+')
        else:
            predicted_labels.append('-')

    
    actual_labels = dev_data['Label'].tolist()
    accuracy = accuracy_score(actual_labels, predicted_labels)
    print("Accuracy on dev_data:", accuracy)
# Out:
# epoch 1, update 32.0%, dev 25.0%
# epoch 2, update 30.4%, dev 25.1%
# epoch 3, update 30.3%, dev 24.4%
# epoch 4, update 29.9%, dev 24.2%
# epoch 5, update 30.4%, dev 24.2%
# epoch 6, update 30.7%, dev 24.5%
# epoch 7, update 30.4%, dev 24.3%
# epoch 8, update 30.1%, dev 24.5%
# epoch 9, update 29.9%, dev 24.7%
# epoch 10, update 30.2%, dev 24.7%
# best dev err 24.2%, time: 6.8 secs
# Number of correct examples found: 761
# Example Index: 0, Predicted Label: -
# Review: you could easily mistake it for a sketchy work in progress that was inexplicably rushed to the megaplexes before its time
# ------------------------------------------------------------
# Example Index: 2, Predicted Label: -
# Review: the film is so packed with subplots involving the various silbersteins that it feels more like the pilot episode of a tv series than a feature film
# ------------------------------------------------------------
# Example Index: 5, Predicted Label: +
# Review: escapism in its purest form
# ------------------------------------------------------------
# Example Index: 6, Predicted Label: +
# Review: nicole kidman makes it a party worth attending
# ------------------------------------------------------------
# Example Index: 8, Predicted Label: +
# Review: a real audience pleaser that will strike a chord with anyone who 's ever waited in a doctor 's office , emergency room , hospital bed or insurance company office
# ------------------------------------------------------------
# Example Index: 9, Predicted Label: +
# Review: a touching drama about old age and grief with a tour de force performance by michel piccoli
# ------------------------------------------------------------
# Example Index: 11, Predicted Label: -
# Review: two tedious acts light on great scares and a good surprise ending
# ------------------------------------------------------------
# Example Index: 12, Predicted Label: +
# Review: the beauty of alexander payne 's ode to the everyman is in the details
# ------------------------------------------------------------
# Example Index: 13, Predicted Label: -
# Review: a pint sized ` goodfellas ' designed to appeal to the younger set , it 's not a very good movie in any objective sense , but it does mostly hold one 's interest
# ------------------------------------------------------------
# Example Index: 15, Predicted Label: -
# Review: barrels along at the start before becoming mired in sentimentality
# ------------------------------------------------------------
# Example Index: 16, Predicted Label: -
# Review: a yawn provoking little farm melodrama
# ------------------------------------------------------------
# Example Index: 17, Predicted Label: -
# Review: the irwins ' scenes are fascinating the movie as a whole is cheap junk and an insult to their death defying efforts
# ------------------------------------------------------------
# Example Index: 18, Predicted Label: -
# Review: friday after next is a lot more bluster than bite
# ------------------------------------------------------------
# Example Index: 19, Predicted Label: -
# Review: like a fish that 's lived too long , austin powers in goldmember has some unnecessary parts and is kinda wrong in places
# ------------------------------------------------------------
# Example Index: 20, Predicted Label: +
# Review: a soul stirring documentary about the israeli palestinian conflict as revealed through the eyes of some children who remain curious about each other against all odds
# ------------------------------------------------------------
# Example Index: 21, Predicted Label: -
# Review: an empty , ugly exercise in druggy trance noir and trumped up street credibility
# ------------------------------------------------------------
# Example Index: 22, Predicted Label: -
# Review: a loud , brash and mainly unfunny high school comedy
# ------------------------------------------------------------
# Example Index: 23, Predicted Label: +
# Review: a serviceable euro trash action extravaganza , with a decent sense of humor and plenty of things that go boom handguns , bmws and seaside chateaus
# ------------------------------------------------------------
# Example Index: 24, Predicted Label: -
# Review: spreads itself too thin , leaving these actors , as well as the members of the commune , short of profound characterizations
# ------------------------------------------------------------
# Example Index: 25, Predicted Label: +
# Review: one of the most original american productions this year , you 'll find yourself remembering this refreshing visit to a sunshine state
# ------------------------------------------------------------
# Example Index: 26, Predicted Label: -
# Review: it 's a long way from orwell 's dark , intelligent warning cry 1984 to the empty stud knockabout of equilibrium , and what once was conviction is now affectation
# ------------------------------------------------------------
# Example Index: 27, Predicted Label: -
# Review: this is a movie filled with unlikable , spiteful idiots whether or not their friendship is salvaged makes no difference in the least
# ------------------------------------------------------------
# Example Index: 28, Predicted Label: -
# Review: there 's not a fresh idea at the core of this tale
# ------------------------------------------------------------
# Example Index: 29, Predicted Label: +
# Review: colorful , energetic and sweetly whimsical the rare sequel that 's better than its predecessor
# ------------------------------------------------------------
# Example Index: 30, Predicted Label: -
# Review: oversexed , at times overwrought comedy drama that offers little insight into the experience of being forty , female and single
# ------------------------------------------------------------
# Example Index: 31, Predicted Label: +
# Review: writer director david jacobson and his star , jeremy renner , have made a remarkable film that explores the monster 's psychology not in order to excuse him but rather to demonstrate that his pathology evolved from human impulses that grew hideously twisted
# ------------------------------------------------------------
# Example Index: 32, Predicted Label: -
# Review: unlike trey parker , sandler does n't understand that the idea of exploiting molestation for laughs is funny , not actually exploiting it yourself
# ------------------------------------------------------------
# Example Index: 34, Predicted Label: -
# Review: get out your pooper scoopers
# ------------------------------------------------------------
# Example Index: 36, Predicted Label: -
# Review: i have no problem with difficult movies , or movies that ask the audience to meet them halfway and connect the dots instead of having things all spelled out but first , you have to give the audience a reason to b want b to put for that effort , and i
# ------------------------------------------------------------
# Example Index: 37, Predicted Label: +
# Review: you 've already seen city by the sea under a variety of titles , but it 's worth yet another visit
# ------------------------------------------------------------
# Example Index: 38, Predicted Label: +
# Review: like smoke signals , the film is also imbued with strong themes of familial ties and spirituality that are powerful and moving without stooping to base melodrama
# ------------------------------------------------------------
# Example Index: 39, Predicted Label: -
# Review: to the filmmakers , ivan is a prince of a fellow , but he comes across as shallow and glib though not mean spirited , and there 's no indication that he 's been responsible for putting together any movies of particular value or merit
# ------------------------------------------------------------
# Example Index: 41, Predicted Label: +
# Review: is funny in the way that makes you ache with sadness ( the way chekhov is funny ) , profound without ever being self important , warm without ever succumbing to sentimentality
# ------------------------------------------------------------
# Example Index: 42, Predicted Label: -
# Review: this little film is so slovenly done , so primitive in technique , that it ca n't really be called animation
# ------------------------------------------------------------
# Example Index: 43, Predicted Label: +
# Review: a funny yet dark and seedy clash of cultures and generations
# ------------------------------------------------------------
# Example Index: 44, Predicted Label: +
# Review: will certainly appeal to asian cult cinema fans and asiaphiles interested to see what all the fuss is about
# ------------------------------------------------------------
# Example Index: 45, Predicted Label: -
# Review: like schindler 's list , the grey zone attempts to be grandiloquent , but ends up merely pretentious in a grisly sort of way
# ------------------------------------------------------------
# Example Index: 46, Predicted Label: +
# Review: if signs is a good film , and it is , the essence of a great one is in there somewhere
# ------------------------------------------------------------
# Example Index: 47, Predicted Label: -
# Review: ah nuld 's action hero days might be over
# ------------------------------------------------------------
# Example Index: 48, Predicted Label: -
# Review: what ` blade runner ' would 've looked like as a low budget series on a uhf channel
# ------------------------------------------------------------
# Example Index: 49, Predicted Label: -
# Review: a shoddy male hip hop fantasy filled with guns , expensive cars , lots of naked women and rocawear clothing
# ------------------------------------------------------------
# Example Index: 50, Predicted Label: +
# Review: drama of temptation , salvation and good intentions is a thoughtful examination of faith , love and power
# ------------------------------------------------------------
# Example Index: 51, Predicted Label: -
# Review: it 's as if a bored cage spent the duration of the film 's shooting schedule waiting to scream got aids yet ?
# ------------------------------------------------------------
# Example Index: 52, Predicted Label: +
# Review: the entire movie has a truncated feeling , but what 's available is lovely and lovable
# ------------------------------------------------------------
# Example Index: 53, Predicted Label: -
# Review: paul bettany is good at being the ultra violent gangster wannabe , but the movie is certainly not number 1
# ------------------------------------------------------------
# Example Index: 54, Predicted Label: -
# Review: this tuxedo should have been sent back to the tailor for some major alterations
# ------------------------------------------------------------
# Example Index: 55, Predicted Label: +
# Review: a rather brilliant little cult item a pastiche of children 's entertainment , superhero comics , and japanese animation
# ------------------------------------------------------------
# Example Index: 56, Predicted Label: -
# Review: mandel holland 's direction is uninspired , and his scripting unsurprising , but the performances by phifer and black are ultimately winning you 'll find yourself wishing that you and they were in another movie
# ------------------------------------------------------------
# Example Index: 57, Predicted Label: +
# Review: his work transcends the boy meets girl posturing of typical love stories
# ------------------------------------------------------------
# Example Index: 59, Predicted Label: -
# Review: feels like the work of an artist who is simply tired of fighting the same fights , of putting the weight of the world on his shoulders , of playing with narrative form
# ------------------------------------------------------------
# Example Index: 60, Predicted Label: -
# Review: what happens when something goes bump in the night and nobody cares ?
# ------------------------------------------------------------
# Example Index: 61, Predicted Label: -
# Review: toback 's fondness for fancy split screen , stuttering editing and pompous references to wittgenstein and kirkegaard blends uneasily with the titillating material
# ------------------------------------------------------------
# Example Index: 63, Predicted Label: +
# Review: although largely a heavy handed indictment of parental failings and the indifference of spanish social workers and legal system towards child abuse , the film retains ambiguities that make it well worth watching
# ------------------------------------------------------------
# Example Index: 65, Predicted Label: +
# Review: twenty years after its first release , e t remains the most wondrous of all hollywood fantasies and the apex of steven spielberg 's misunderstood career
# ------------------------------------------------------------
# Example Index: 66, Predicted Label: -
# Review: sunk by way too much indulgence of scene chewing , teeth gnashing actorliness
# ------------------------------------------------------------
# Example Index: 69, Predicted Label: +
# Review: who is the audience for cletis tout ? anybody who enjoys quirky , fun , popcorn movies with a touch of silliness and a little bloodshed
# ------------------------------------------------------------
# Example Index: 71, Predicted Label: -
# Review: unfortunately , contrived plotting , stereotyped characters and woo 's over the top instincts as a director undermine the moral dilemma at the movie 's heart
# ------------------------------------------------------------
# Example Index: 72, Predicted Label: +
# Review: the byplay and bickering between the now spy savvy siblings , carmen ( vega ) and juni ( sabara ) cortez , anchor the film in a very real and amusing give and take
# ------------------------------------------------------------
# Example Index: 74, Predicted Label: -
# Review: suffers from unlikable characters and a self conscious sense of its own quirky hipness
# ------------------------------------------------------------
# Example Index: 75, Predicted Label: -
# Review: was that movie nothing more than a tepid exercise in trotting out a formula that worked five years ago but has since lost its fizz ?
# ------------------------------------------------------------
# Example Index: 76, Predicted Label: +
# Review: i liked a lot of the smaller scenes
# ------------------------------------------------------------
# Example Index: 78, Predicted Label: +
# Review: one of the pleasures in walter 's documentary is the parade of veteran painters , confounded dealers , and miscellaneous bohos who expound upon the subject 's mysterious personality without ever explaining him
# ------------------------------------------------------------
# Example Index: 79, Predicted Label: -
# Review: about as original as a gangster sweating bullets while worrying about a contract on his life
# ------------------------------------------------------------
# Example Index: 81, Predicted Label: -
# Review: if there was ever a movie where the upbeat ending feels like a copout , this is the one
# ------------------------------------------------------------
# Example Index: 83, Predicted Label: +
# Review: late marriage is an in your face family drama and black comedy that is filled with raw emotions conveying despair and love
# ------------------------------------------------------------
# Example Index: 84, Predicted Label: +
# Review: though it flirts with bathos and pathos and the further oprahfication of the world as we know it , it still cuts all the way down to broken bone
# ------------------------------------------------------------
# Example Index: 85, Predicted Label: -
# Review: one of the worst movies of the year
# ------------------------------------------------------------
# Example Index: 86, Predicted Label: +
# Review: the film fearlessly gets under the skin of the people involved this makes it not only a detailed historical document , but an engaging and moving portrait of a subculture
# ------------------------------------------------------------
# Example Index: 88, Predicted Label: +
# Review: the performances are strong , though the subject matter demands acting that borders on hammy at times
# ------------------------------------------------------------
# Example Index: 89, Predicted Label: +
# Review: full of bland hotels , highways , parking lots , with some glimpses of nature and family warmth , time out is a discreet moan of despair about entrapment in the maze of modern life
# ------------------------------------------------------------
# Example Index: 90, Predicted Label: -
# Review: it goes on for too long and bogs down in a surfeit of characters and unnecessary subplots
# ------------------------------------------------------------
# Example Index: 91, Predicted Label: +
# Review: it may scream low budget , but this charmer has a spirit that can not be denied
# ------------------------------------------------------------
# Example Index: 92, Predicted Label: -
# Review: presents nothing special and , until the final act , nothing overtly disagreeable
# ------------------------------------------------------------
# Example Index: 94, Predicted Label: -
# Review: not only does leblanc make one spectacularly ugly looking broad , but he appears miserable throughout as he swaggers through his scenes
# ------------------------------------------------------------
# Example Index: 95, Predicted Label: +
# Review: at its worst , the movie is pretty diverting the pity is that it rarely achieves its best
# ------------------------------------------------------------
# Example Index: 97, Predicted Label: +
# Review: the film oozes craft
# ------------------------------------------------------------
# Example Index: 98, Predicted Label: +
# Review: a compelling french psychological drama examining the encounter of an aloof father and his chilly son after 20 years apart
# ------------------------------------------------------------
# Example Index: 103, Predicted Label: +
# Review: try as you might to scrutinize the ethics of kaufman 's approach , somehow it all comes together to create a very compelling , sensitive , intelligent and almost cohesive piece of film entertainment
# ------------------------------------------------------------
# Example Index: 104, Predicted Label: -
# Review: although purportedly a study in modern alienation , it 's really little more than a particularly slanted , gay s m fantasy , enervating and deadeningly drawn out
# ------------------------------------------------------------
# Example Index: 105, Predicted Label: -
# Review: a fairly harmless but ultimately lifeless feature length afterschool special
# ------------------------------------------------------------
# Example Index: 106, Predicted Label: -
# Review: a sustained fest of self congratulation between actor and director that leaves scant place for the viewer
# ------------------------------------------------------------
# Example Index: 107, Predicted Label: -
# Review: i 'm not sure which will take longer to heal the welt on johnny knoxville 's stomach from a riot control projectile or my own tortured psyche
# ------------------------------------------------------------
# Example Index: 108, Predicted Label: -
# Review: this is an exercise not in biography but in hero worship
# ------------------------------------------------------------
# Example Index: 109, Predicted Label: -
# Review: tv skit com material fervently deposited on the big screen
# ------------------------------------------------------------
# Example Index: 110, Predicted Label: -
# Review: everything that was right about blade is wrong in its sequel
# ------------------------------------------------------------
# Example Index: 111, Predicted Label: -
# Review: replacing john carpenter 's stylish tracking shots is degraded , handheld blair witch video cam footage of all the halloween 's , this is the most visually unappealing
# ------------------------------------------------------------
# Example Index: 112, Predicted Label: -
# Review: the film rehashes several old themes and is capped with pointless extremes it 's insanely violent and very graphic
# ------------------------------------------------------------
# Example Index: 113, Predicted Label: +
# Review: one of those movies that make us pause and think of what we have given up to acquire the fast paced contemporary society
# ------------------------------------------------------------
# Example Index: 114, Predicted Label: -
# Review: aspires to the cracked lunacy of the adventures of buckaroo banzai , but thanks to an astonishingly witless script ends up more like the adventures of ford fairlane
# ------------------------------------------------------------
# Example Index: 115, Predicted Label: -
# Review: showtime is n't particularly assaultive , but it can still make you feel that you never want to see another car chase , explosion or gunfight again
# ------------------------------------------------------------
# Example Index: 117, Predicted Label: +
# Review: ferrera has the charisma of a young woman who knows how to hold the screen
# ------------------------------------------------------------
# Example Index: 118, Predicted Label: +
# Review: here is a vh1 behind the music special that has something a little more special behind it music that did n't sell many records but helped change a nation
# ------------------------------------------------------------
# Example Index: 119, Predicted Label: +
# Review: a powerful sequel and one of the best films of the year
# ------------------------------------------------------------
# Example Index: 120, Predicted Label: -
# Review: so verbally flatfooted and so emotionally predictable or bland that it plays like the standard made for tv movie
# ------------------------------------------------------------
# Example Index: 122, Predicted Label: -
# Review: ritchie may not have a novel thought in his head , but he knows how to pose madonna
# ------------------------------------------------------------
# Example Index: 123, Predicted Label: +
# Review: it 's a good film , but it falls short of its aspiration to be a true ` epic '
# ------------------------------------------------------------
# Example Index: 124, Predicted Label: +
# Review: as it turns out , you can go home again
# ------------------------------------------------------------
# Example Index: 126, Predicted Label: -
# Review: ultimately , the film never recovers from the clumsy clich of the ugly american abroad , and the too frosty exterior ms paltrow employs to authenticate her british persona is another liability
# ------------------------------------------------------------
# Example Index: 127, Predicted Label: -
# Review: rarely has sex on screen been so aggressively anti erotic
# ------------------------------------------------------------
# Example Index: 130, Predicted Label: +
# Review: the film is delicately narrated by martin landau and directed with sensitivity and skill by dana janklowicz mann
# ------------------------------------------------------------
# Example Index: 131, Predicted Label: -
# Review: did no one on the set have a sense of humor , or did they not have the nerve to speak up ?
# ------------------------------------------------------------
# Example Index: 133, Predicted Label: -
# Review: a generic bloodbath that often becomes laughably unbearable when it is n't merely offensive
# ------------------------------------------------------------
# Example Index: 134, Predicted Label: -
# Review: no one can doubt the filmmakers ' motives , but the guys still feels counterproductive
# ------------------------------------------------------------
# Example Index: 135, Predicted Label: -
# Review: the film 's final hour , where nearly all the previous unseen material resides , is unconvincing soap opera that tornatore was right to cut
# ------------------------------------------------------------
# Example Index: 136, Predicted Label: -
# Review: unspeakable , of course , barely begins to describe the plot and its complications vulgar is too optimistic a title
# ------------------------------------------------------------
# Example Index: 137, Predicted Label: +
# Review: art house to the core , read my lips is a genre curling crime story that revives the free wheeling noir spirit of old french cinema
# ------------------------------------------------------------
# Example Index: 139, Predicted Label: +
# Review: both an admirable reconstruction of terrible events , and a fitting memorial to the dead of that day , and of the thousands thereafter
# ------------------------------------------------------------
# Example Index: 140, Predicted Label: -
# Review: this is standard crime drama fare instantly forgettable and thoroughly dull
# ------------------------------------------------------------
# Example Index: 141, Predicted Label: -
# Review: memorable for a peculiar malaise that renders its tension flaccid and , by extension , its surprises limp and its resolutions ritual
# ------------------------------------------------------------
# Example Index: 142, Predicted Label: -
# Review: ultimately , jane learns her place as a girl , softens up and loses some of the intensity that made her an interesting character to begin with
# ------------------------------------------------------------
# Example Index: 143, Predicted Label: +
# Review: even if you 've never heard of chaplin , you 'll still be glued to the screen
# ------------------------------------------------------------
# Example Index: 144, Predicted Label: +
# Review: it is hard not to be especially grateful for freedom after a film like this
# ------------------------------------------------------------
# Example Index: 145, Predicted Label: +
# Review: the story that emerges has elements of romance , tragedy and even silent movie comedy
# ------------------------------------------------------------
# Example Index: 146, Predicted Label: -
# Review: tom green and an ivy league college should never appear together on a marquee , especially when the payoff is an unschooled comedy like stealing harvard , which fails to keep 80 minutes from seeming like 800
# ------------------------------------------------------------
# Example Index: 147, Predicted Label: +
# Review: together time out and human resources establish mr cantet as france 's foremost cinematic poet of the workplace
# ------------------------------------------------------------
# Example Index: 148, Predicted Label: -
# Review: the dramatic scenes are frequently unintentionally funny , and the action sequences clearly the main event are surprisingly uninvolving
# ------------------------------------------------------------
# Example Index: 149, Predicted Label: -
# Review: you expect more from director michael apted ( enigma ) and screenwriter nicholas kazan ( reversal of fortune ) than this cliche pileup
# ------------------------------------------------------------
# Example Index: 150, Predicted Label: -
# Review: what the audience feels is exhaustion , from watching a movie that is dark ( dark green , to be exact ) , sour , bloody and mean
# ------------------------------------------------------------
# Example Index: 151, Predicted Label: -
# Review: in his role of observer of the scene , lawrence sounds whiny and defensive , as if his life altering experiences made him bitter and less mature
# ------------------------------------------------------------
# Example Index: 152, Predicted Label: +
# Review: beautifully shot against the frozen winter landscapes of grenoble and geneva , the film unfolds with all the mounting tension of an expert thriller , until the tragedy beneath it all gradually reveals itself
# ------------------------------------------------------------
# Example Index: 153, Predicted Label: -
# Review: they presume their audience wo n't sit still for a sociology lesson , however entertainingly presented , so they trot out the conventional science fiction elements of bug eyed monsters and futuristic women in skimpy clothes
# ------------------------------------------------------------
# Example Index: 154, Predicted Label: +
# Review: its compelling mix of trial movie , escape movie and unexpected fable ensures the film never feels draggy
# ------------------------------------------------------------
# Example Index: 155, Predicted Label: +
# Review: admirers of director abel ferrara may be relieved that his latest feature , r xmas , marks a modest if encouraging return to form
# ------------------------------------------------------------
# Example Index: 156, Predicted Label: +
# Review: count on his movie to work at the back of your neck long after you leave the theater
# ------------------------------------------------------------
# Example Index: 158, Predicted Label: -
# Review: i 'm not sure which is worse the poor acting by the ensemble cast , the flat dialogue by vincent r nebrida or the gutless direction by laurice guillen
# ------------------------------------------------------------
# Example Index: 161, Predicted Label: -
# Review: enough is not a bad movie , just mediocre the performances are so overstated , the effect comes off as self parody
# ------------------------------------------------------------
# Example Index: 162, Predicted Label: +
# Review: a bilingual charmer , just like the woman who inspired it
# ------------------------------------------------------------
# Example Index: 163, Predicted Label: -
# Review: when the precise nature of matthew 's predicament finally comes into sharp focus , the revelation fails to justify the build up
# ------------------------------------------------------------
# Example Index: 164, Predicted Label: +
# Review: may not be a breakthrough in filmmaking , but it is unwavering and arresting
# ------------------------------------------------------------
# Example Index: 165, Predicted Label: -
# Review: lacks the visual flair and bouncing bravado that characterizes better hip hop clips and is content to recycle images and characters that were already tired 10 years ago
# ------------------------------------------------------------
# Example Index: 166, Predicted Label: -
# Review: family togetherness takes a back seat to inter family rivalry and workplace ambition 133 whole subplots have no explanation or even plot relevance
# ------------------------------------------------------------
# Example Index: 168, Predicted Label: +
# Review: savvy director robert j siegel and his co writers keep the story subtle and us in suspense
# ------------------------------------------------------------
# Example Index: 169, Predicted Label: +
# Review: the determination of pinochet 's victims to seek justice , and their often heartbreaking testimony , spoken directly into director patricio guzman 's camera , pack a powerful emotional wallop
# ------------------------------------------------------------
# Example Index: 170, Predicted Label: -
# Review: do we really need another film that praises female self sacrifice ?
# ------------------------------------------------------------
# Example Index: 171, Predicted Label: +
# Review: the film sometimes flags but there is enough secondary action to keep things moving along at a brisk , amusing pace
# ------------------------------------------------------------
# Example Index: 173, Predicted Label: -
# Review: the result is good gossip , entertainingly delivered , yet with a distinctly musty odour , its expiry date long gone
# ------------------------------------------------------------
# Example Index: 174, Predicted Label: -
# Review: at once overly old fashioned in its sudsy plotting and heavy handed in its effort to modernize it with encomia to diversity and tolerance
# ------------------------------------------------------------
# Example Index: 176, Predicted Label: +
# Review: open ended and composed of layer upon layer , talk to her is a cinephile 's feast , an invitation to countless interpretations
# ------------------------------------------------------------
# Example Index: 177, Predicted Label: -
# Review: i liked the original short story but this movie , even at an hour and twenty some minutes , it 's too long and it goes nowhere
# ------------------------------------------------------------
# Example Index: 179, Predicted Label: -
# Review: mckay shows crushingly little curiosity about , or is ill equipped to examine , the interior lives of the characters in his film , much less incorporate them into his narrative
# ------------------------------------------------------------
# Example Index: 180, Predicted Label: +
# Review: a small gem of a movie that defies classification and is as thought provoking as it is funny , scary and sad
# ------------------------------------------------------------
# Example Index: 181, Predicted Label: +
# Review: evokes the style and flash of the double cross that made mamet 's house of games and last fall 's heist so much fun
# ------------------------------------------------------------
# Example Index: 182, Predicted Label: +
# Review: a cutesy romantic tale with a twist
# ------------------------------------------------------------
# Example Index: 183, Predicted Label: +
# Review: a harrowing account of a psychological breakdown
# ------------------------------------------------------------
# Example Index: 184, Predicted Label: +
# Review: works on some levels and is certainly worth seeing at least once
# ------------------------------------------------------------
# Example Index: 186, Predicted Label: -
# Review: in the not too distant future , movies like ghost ship will be used as analgesic balm for overstimulated minds right now , they 're merely signposts marking the slow , lingering death of imagination
# ------------------------------------------------------------
# Example Index: 187, Predicted Label: +
# Review: overall , it 's a wacky and inspired little film that works effortlessly at delivering genuine , acerbic laughs
# ------------------------------------------------------------
# Example Index: 189, Predicted Label: -
# Review: a few energetic stunt sequences briefly enliven the film , but the wheezing terrorist subplot has n't the stamina for the 100 minute running time , and the protagonists ' bohemian boorishness mars the spirit of good clean fun
# ------------------------------------------------------------
# Example Index: 191, Predicted Label: +
# Review: exciting and well paced
# ------------------------------------------------------------
# Example Index: 192, Predicted Label: +
# Review: the complex , politically charged tapestry of contemporary chinese life this exciting new filmmaker has brought to the screen is like nothing we westerners have seen before
# ------------------------------------------------------------
# Example Index: 193, Predicted Label: -
# Review: an empty , purposeless exercise
# ------------------------------------------------------------
# Example Index: 195, Predicted Label: -
# Review: with its lackadaisical plotting and mindless action , all about the benjamins evokes the bottom tier of blaxploitation flicks from the 1970s
# ------------------------------------------------------------
# Example Index: 196, Predicted Label: -
# Review: you get a sense of good intentions derailed by a failure to seek and strike just the right tone
# ------------------------------------------------------------
# Example Index: 197, Predicted Label: +
# Review: a powerful , inflammatory film about religion that dares to question an ancient faith , and about hatred that offers no easy , comfortable resolution
# ------------------------------------------------------------
# Example Index: 198, Predicted Label: +
# Review: the hypnotic imagery and fragmentary tale explore the connections between place and personal identity
# ------------------------------------------------------------
# Example Index: 199, Predicted Label: -
# Review: after the first 10 minutes , which is worth seeing , the movie sinks into an abyss of clich s , depression and bad alternative music
# ------------------------------------------------------------
# Example Index: 201, Predicted Label: -
# Review: not everything in the film works , including its somewhat convenient ending
# ------------------------------------------------------------
# Example Index: 203, Predicted Label: +
# Review: this film is an act of spiritual faith an eloquent , deeply felt meditation on the nature of compassion
# ------------------------------------------------------------
# Example Index: 204, Predicted Label: +
# Review: consistently clever and suspenseful
# ------------------------------------------------------------
# Example Index: 205, Predicted Label: -
# Review: so much about the film is loopy and ludicrous that it could have been a hoot in a bad movie way if the laborious pacing and endless exposition had been tightened
# ------------------------------------------------------------
# Example Index: 207, Predicted Label: +
# Review: intriguing and downright intoxicating
# ------------------------------------------------------------
# Example Index: 209, Predicted Label: -
# Review: the actors pull out all the stops in nearly every scene , but to diminishing effect the characters never change
# ------------------------------------------------------------
# Example Index: 211, Predicted Label: +
# Review: lovingly photographed in the manner of a golden book sprung to life , stuart little 2 manages sweetness largely without stickiness
# ------------------------------------------------------------
# Example Index: 212, Predicted Label: +
# Review: simone is a fun and funky look into an artificial creation in a world that thrives on artificiality
# ------------------------------------------------------------
# Example Index: 214, Predicted Label: +
# Review: the action sequences are fun and reminiscent of combat scenes from the star wars series
# ------------------------------------------------------------
# Example Index: 216, Predicted Label: +
# Review: a good film that must have baffled the folks in the marketing department
# ------------------------------------------------------------
# Example Index: 217, Predicted Label: +
# Review: like the rugrats movies , the wild thornberrys movie does n't offer much more than the series , but its emphasis on caring for animals and respecting other cultures is particularly welcome
# ------------------------------------------------------------
# Example Index: 218, Predicted Label: -
# Review: the title , alone , should scare any sane person away
# ------------------------------------------------------------
# Example Index: 219, Predicted Label: +
# Review: if the real life story is genuinely inspirational , the movie stirs us as well
# ------------------------------------------------------------
# Example Index: 220, Predicted Label: -
# Review: will no doubt delight plympton 's legion of fans others may find 80 minutes of these shenanigans exhausting
# ------------------------------------------------------------
# Example Index: 221, Predicted Label: +
# Review: cool gadgets and creatures keep this fresh not as good as the original , but what is
# ------------------------------------------------------------
# Example Index: 222, Predicted Label: -
# Review: one long , numbing action sequence made up mostly of routine stuff yuen has given us before
# ------------------------------------------------------------
# Example Index: 223, Predicted Label: -
# Review: the story of trouble every day is so sketchy it amounts to little more than preliminary notes for a science fiction horror film , and the movie 's fragmentary narrative style makes piecing the story together frustrating difficult
# ------------------------------------------------------------
# Example Index: 225, Predicted Label: +
# Review: a thoughtful , reverent portrait of what is essentially a subculture , with its own rules regarding love and family , governance and hierarchy
# ------------------------------------------------------------
# Example Index: 226, Predicted Label: -
# Review: jackson and bledel seem to have been picked not for their acting chops , but for their looks and appeal to the pre teen crowd
# ------------------------------------------------------------
# Example Index: 227, Predicted Label: +
# Review: a must see for all sides of the political spectrum
# ------------------------------------------------------------
# Example Index: 228, Predicted Label: +
# Review: quite good at providing some good old fashioned spooks
# ------------------------------------------------------------
# Example Index: 229, Predicted Label: -
# Review: the whole thing succeeded only in making me groggy
# ------------------------------------------------------------
# Example Index: 230, Predicted Label: -
# Review: has its moments , but ultimately , its curmudgeon does n't quite make the cut of being placed on any list of favorites
# ------------------------------------------------------------
# Example Index: 231, Predicted Label: +
# Review: to those who have not read the book , the film is a much better mother daughter tale than last summer 's ` divine secrets of the ya ya sisterhood , ' but that 's not saying much
# ------------------------------------------------------------
# Example Index: 232, Predicted Label: -
# Review: show me the mugging
# ------------------------------------------------------------
# Example Index: 233, Predicted Label: +
# Review: a stylish cast and some clever scripting solutions help chicago make the transition from stage to screen with considerable appeal intact
# ------------------------------------------------------------
# Example Index: 234, Predicted Label: +
# Review: the messy emotions raging throughout this three hour effort are instantly recognizable , allowing the film to paradoxically feel familiar and foreign at the same time
# ------------------------------------------------------------
# Example Index: 235, Predicted Label: +
# Review: good actors have a radar for juicy roles there 's a plethora of characters in this picture , and not one of them is flat
# ------------------------------------------------------------
# Example Index: 236, Predicted Label: -
# Review: ` in this poor remake of such a well loved classic , parker exposes the limitations of his skill and the basic flaws in his vision '
# ------------------------------------------------------------
# Example Index: 237, Predicted Label: +
# Review: harks back to a time when movies had more to do with imagination than market research
# ------------------------------------------------------------
# Example Index: 238, Predicted Label: -
# Review: michele is a such a brainless flibbertigibbet that it 's hard to take her spiritual quest at all seriously
# ------------------------------------------------------------
# Example Index: 239, Predicted Label: -
# Review: it 's not too fast and not too slow it 's not too racy and it 's not too offensive it 's not too much of anything
# ------------------------------------------------------------
# Example Index: 240, Predicted Label: +
# Review: it 's worth the extra effort to see an artist , still committed to growth in his ninth decade , change while remaining true to his principles with a film whose very subject is , quite pointedly , about the peril of such efforts
# ------------------------------------------------------------
# Example Index: 241, Predicted Label: +
# Review: is not so much a work of entertainment as it is a unique , well crafted psychological study of grief
# ------------------------------------------------------------
# Example Index: 243, Predicted Label: -
# Review: does n't add up to much
# ------------------------------------------------------------
# Example Index: 244, Predicted Label: +
# Review: veret has a whip smart sense of narrative bluffs
# ------------------------------------------------------------
# Example Index: 245, Predicted Label: +
# Review: jeff 's gorgeous , fluid compositions , underlined by neil finn and edmund mcwilliams 's melancholy music , are charged with metaphor , but rarely easy , obvious or self indulgent
# ------------------------------------------------------------
# Example Index: 246, Predicted Label: -
# Review: an opportunity missed
# ------------------------------------------------------------
# Example Index: 247, Predicted Label: +
# Review: the film is small in scope , yet perfectly formed
# ------------------------------------------------------------
# Example Index: 248, Predicted Label: -
# Review: there are cheesy backdrops , ridiculous action sequences , and many tired jokes about men in heels
# ------------------------------------------------------------
# Example Index: 249, Predicted Label: +
# Review: full of detail about the man and his country , and is well worth seeing
# ------------------------------------------------------------
# Example Index: 251, Predicted Label: -
# Review: when ` science fiction ' takes advantage of the fact that its intended audience has n't yet had much science , it does a disservice to the audience and to the genre
# ------------------------------------------------------------
# Example Index: 252, Predicted Label: -
# Review: the major problem with windtalkers is that the bulk of the movie centers on the wrong character
# ------------------------------------------------------------
# Example Index: 253, Predicted Label: -
# Review: the most excruciating 86 minutes one might sit through this summer that do not involve a dentist drill
# ------------------------------------------------------------
# Example Index: 254, Predicted Label: +
# Review: moretti is the rare common man artist who 's wise enough to recognize that there are few things in this world more complex and , as it turns out , more fragile than happiness
# ------------------------------------------------------------
# Example Index: 256, Predicted Label: +
# Review: it 's an exhilarating place to visit , this laboratory of laughter
# ------------------------------------------------------------
# Example Index: 259, Predicted Label: -
# Review: the script feels as if it started to explore the obvious voyeuristic potential of ` hypertime ' but then backed off when the producers saw the grosses for spy kids
# ------------------------------------------------------------
# Example Index: 260, Predicted Label: +
# Review: it will break your heart many times over
# ------------------------------------------------------------
# Example Index: 261, Predicted Label: +
# Review: over the years , hollywood has crafted a solid formula for successful animated movies , and ice age only improves on it , with terrific computer graphics , inventive action sequences and a droll sense of humor
# ------------------------------------------------------------
# Example Index: 263, Predicted Label: -
# Review: the leads we are given here are simply too bland to be interesting
# ------------------------------------------------------------
# Example Index: 265, Predicted Label: +
# Review: it 's the unsettling images of a war ravaged land that prove more potent and riveting than the unlikely story of sarah and harrison
# ------------------------------------------------------------
# Example Index: 267, Predicted Label: +
# Review: although shot with little style , skins is heartfelt and achingly real
# ------------------------------------------------------------
# Example Index: 268, Predicted Label: +
# Review: a good music documentary , probably one of the best since the last waltz
# ------------------------------------------------------------
# Example Index: 275, Predicted Label: -
# Review: there 's surely something wrong with a comedy where the only belly laughs come from the selection of outtakes tacked onto the end credits
# ------------------------------------------------------------
# Example Index: 276, Predicted Label: +
# Review: on guard ! wo n't be placed in the pantheon of the best of the swashbucklers but it is a whole lot of fun and you get to see the one of the world 's best actors , daniel auteuil , have a whale of a good time
# ------------------------------------------------------------
# Example Index: 277, Predicted Label: +
# Review: disney aficionados will notice distinct parallels between this story and the 1971 musical bedknobs and broomsticks , which also dealt with british children rediscovering the power of fantasy during wartime
# ------------------------------------------------------------
# Example Index: 279, Predicted Label: -
# Review: visually exciting sci fi film which suffers from a lackluster screenplay
# ------------------------------------------------------------
# Example Index: 280, Predicted Label: +
# Review: an ebullient tunisian film about the startling transformation of a tradition bound widow who is drawn into the exotic world of belly dancing
# ------------------------------------------------------------
# Example Index: 281, Predicted Label: +
# ...
# ------------------------------------------------------------
# Example Index: 905, Predicted Label: -
# Review: the following things are not at all entertaining the bad sound , the lack of climax and , worst of all , watching seinfeld ( who is also one of the film 's producers ) do everything he can to look like a good guy
# ------------------------------------------------------------
# Example Index: 906, Predicted Label: +
# Review: about schmidt belongs to nicholson gone are the flamboyant mannerisms that are the trademark of several of his performances as schmidt , nicholson walks with a slow , deliberate gait , chooses his words carefully and subdues his natural exuberance
# ------------------------------------------------------------
# Example Index: 907, Predicted Label: +
# Review: there has been a string of ensemble cast romances recently but peter mattei 's love in the time of money sets itself apart by forming a chain of relationships that come full circle to end on a positive ( if tragic ) note
# ------------------------------------------------------------
# Example Index: 910, Predicted Label: -
# Review: like most movies about the pitfalls of bad behavior circuit gets drawn into the party
# ------------------------------------------------------------
# Example Index: 911, Predicted Label: +
# Review: the filmmaker 's heart is in the right place
# ------------------------------------------------------------
# Example Index: 912, Predicted Label: +
# Review: remarkable for its excellent storytelling , its economical , compressed characterisations and for its profound humanity , it 's an adventure story and history lesson all in one
# ------------------------------------------------------------
# Example Index: 913, Predicted Label: +
# Review: puts to rest any thought that the german film industry can not make a delightful comedy centering on food
# ------------------------------------------------------------
# Example Index: 915, Predicted Label: +
# Review: smith examines the intimate , unguarded moments of folks who live in unusual homes which pop up in nearly every corner of the country
# ------------------------------------------------------------
# Example Index: 916, Predicted Label: -
# Review: an empty shell of an epic rather than the real deal
# ------------------------------------------------------------
# Example Index: 920, Predicted Label: +
# Review: em ash wednesday em is not edward burns ' best film , but it is a good and ambitious film and it marks him as one of the most interesting writer directors working today
# ------------------------------------------------------------
# Example Index: 921, Predicted Label: -
# Review: what begins brightly gets bogged down over 140 minutes
# ------------------------------------------------------------
# Example Index: 923, Predicted Label: +
# Review: a marvel of production design
# ------------------------------------------------------------
# Example Index: 924, Predicted Label: +
# Review: exhilarating , funny and fun
# ------------------------------------------------------------
# Example Index: 925, Predicted Label: +
# Review: so unique and stubborn and charismatic that you want it to be better and more successful than it is
# ------------------------------------------------------------
# Example Index: 926, Predicted Label: -
# Review: certain to be distasteful to children and adults alike , eight crazy nights is a total misfire
# ------------------------------------------------------------
# Example Index: 927, Predicted Label: +
# Review: gloriously straight from the vagina
# ------------------------------------------------------------
# Example Index: 928, Predicted Label: +
# Review: part of the film 's cheeky charm comes from its vintage schmaltz
# ------------------------------------------------------------
# Example Index: 929, Predicted Label: +
# Review: if you like an extreme action packed film with a hint of humor , then triple x marks the spot
# ------------------------------------------------------------
# Example Index: 931, Predicted Label: -
# Review: the animation is competent , and some of the gags are quite funny , but jonah never shakes the oppressive , morally superior good for you quality that almost automatically accompanies didactic entertainment
# ------------------------------------------------------------
# Example Index: 932, Predicted Label: -
# Review: poor ben bratt could n't find stardom if mapquest emailed him point to point driving directions
# ------------------------------------------------------------
# Example Index: 933, Predicted Label: -
# Review: meandering and confusing
# ------------------------------------------------------------
# Example Index: 934, Predicted Label: +
# Review: more sophisticated and literate than such pictures usually are an amusing little catch
# ------------------------------------------------------------
# Example Index: 938, Predicted Label: +
# Review: an enjoyable comedy of lingual and cultural differences the ch teau is a film full of life and small delights that has all the wiggling energy of young kitten
# ------------------------------------------------------------
# Example Index: 939, Predicted Label: +
# Review: the film is an earnest try at beachcombing verismo , but it would be even more indistinct than it is were it not for the striking , quietly vulnerable personality of ms ambrose
# ------------------------------------------------------------
# Example Index: 940, Predicted Label: -
# Review: the entire point of a shaggy dog story , of course , is that it goes nowhere , and this is classic nowheresville in every sense
# ------------------------------------------------------------
# Example Index: 941, Predicted Label: -
# Review: it 's crap on a leash far too polite to scale the lunatic heights of joe dante 's similarly styled gremlins
# ------------------------------------------------------------
# Example Index: 942, Predicted Label: +
# Review: it has a dashing and resourceful hero a lisping , reptilian villain big fights big hair lavish period scenery and a story just complicated enough to let you bask in your own cleverness as you figure it out
# ------------------------------------------------------------
# Example Index: 943, Predicted Label: -
# Review: as self aware movies go , who is cletis tout ? is clever enough , though thin writing proves its undoing
# ------------------------------------------------------------
# Example Index: 944, Predicted Label: -
# Review: loud , silly , stupid and pointless
# ------------------------------------------------------------
# Example Index: 946, Predicted Label: -
# Review: scotland , pa is entirely too straight faced to transcend its clever concept
# ------------------------------------------------------------
# Example Index: 947, Predicted Label: +
# Review: blisteringly rude , scarily funny , sorrowfully sympathetic to the damage it surveys , the film has in kieran culkin a pitch perfect holden
# ------------------------------------------------------------
# Example Index: 949, Predicted Label: -
# Review: a slummer
# ------------------------------------------------------------
# Example Index: 951, Predicted Label: +
# Review: exposing the ways we fool ourselves is one hour photo 's real strength
# ------------------------------------------------------------
# Example Index: 952, Predicted Label: -
# Review: while hollywood ending has its share of belly laughs ( including a knockout of a closing line ) , the movie winds up feeling like a great missed opportunity
# ------------------------------------------------------------
# Example Index: 953, Predicted Label: -
# Review: screenwriter dan schneider and director shawn levy substitute volume and primary colors for humor and bite
# ------------------------------------------------------------
# Example Index: 954, Predicted Label: -
# Review: i ca n't remember the last time i saw a movie where i wanted so badly for the protagonist to fail
# ------------------------------------------------------------
# Example Index: 955, Predicted Label: +
# Review: it seems impossible that an epic four hour indian musical about a cricket game could be this good , but it is
# ------------------------------------------------------------
# Example Index: 958, Predicted Label: +
# Review: grant is certainly amusing , but the very hollowness of the character he plays keeps him at arms length
# ------------------------------------------------------------
# Example Index: 959, Predicted Label: +
# Review: thoroughly engrossing and ultimately tragic
# ------------------------------------------------------------
# Example Index: 961, Predicted Label: -
# Review: a live action cartoon , a fast moving and cheerfully simplistic 88 minutes of exaggerated action put together with the preteen boy in mind
# ------------------------------------------------------------
# Example Index: 963, Predicted Label: +
# Review: a perfectly competent and often imaginative film that lacks what little lilo stitch had in spades charisma
# ------------------------------------------------------------
# Example Index: 964, Predicted Label: +
# Review: not only is it a charming , funny and beautifully crafted import , it uses very little dialogue , making it relatively effortless to read and follow the action at the same time
# ------------------------------------------------------------
# Example Index: 965, Predicted Label: -
# Review: the script was reportedly rewritten a dozen times either 11 times too many or else too few
# ------------------------------------------------------------
# Example Index: 966, Predicted Label: +
# Review: it 's sweet , funny , charming , and completely delightful
# ------------------------------------------------------------
# Example Index: 968, Predicted Label: -
# Review: welles groupie scholar peter bogdanovich took a long time to do it , but he 's finally provided his own broadside at publishing giant william randolph hearst
# ------------------------------------------------------------
# Example Index: 969, Predicted Label: +
# Review: a delightfully unpredictable , hilarious comedy with wonderful performances that tug at your heart in ways that utterly transcend gender labels
# ------------------------------------------------------------
# Example Index: 970, Predicted Label: +
# Review: manages to be both hugely entertaining and uplifting
# ------------------------------------------------------------
# Example Index: 971, Predicted Label: -
# Review: ill considered , unholy hokum
# ------------------------------------------------------------
# Example Index: 973, Predicted Label: -
# Review: the milieu is wholly unconvincing and the histrionics reach a truly annoying pitch
# ------------------------------------------------------------
# Example Index: 974, Predicted Label: +
# Review: taken outside the context of the current political climate ( see terrorists are more evil than ever ! ) , the sum of all fears is simply a well made and satisfying thriller
# ------------------------------------------------------------
# Example Index: 975, Predicted Label: +
# Review: watching e t now , in an era dominated by cold , loud special effects laden extravaganzas , one is struck less by its lavish grandeur than by its intimacy and precision
# ------------------------------------------------------------
# Example Index: 976, Predicted Label: -
# Review: watching junk like this induces a kind of abstract guilt , as if you were paying dues for good books unread , fine music never heard
# ------------------------------------------------------------
# Example Index: 977, Predicted Label: +
# Review: safe conduct is a long movie at 163 minutes but it fills the time with drama , romance , tragedy , bravery , political intrigue , partisans and sabotage viva le resistance !
# ------------------------------------------------------------
# Example Index: 979, Predicted Label: -
# Review: hollywood 's answer to an air ball
# ------------------------------------------------------------
# Example Index: 980, Predicted Label: +
# Review: moore provides an invaluable service by sparking debate and encouraging thought better still , he does all of this , and more , while remaining one of the most savagely hilarious social critics this side of jonathan swift
# ------------------------------------------------------------
# Example Index: 981, Predicted Label: -
# Review: it 's as if solondz had two ideas for two movies , could n't really figure out how to flesh either out , so he just slopped em together here
# ------------------------------------------------------------
# Example Index: 983, Predicted Label: -
# Review: all the characters are clinically depressed and have abandoned their slim hopes and dreams
# ------------------------------------------------------------
# Example Index: 984, Predicted Label: -
# Review: there 's an admirable rigor to jimmy 's relentless anger , and to the script 's refusal of a happy ending , but as those monologues stretch on and on , you realize there 's no place for this story to go but down
# ------------------------------------------------------------
# Example Index: 985, Predicted Label: +
# Review: sometimes charming , sometimes infuriating , this argentinean ` dramedy ' succeeds mainly on the shoulders of its actors
# ------------------------------------------------------------
# Example Index: 986, Predicted Label: +
# Review: upsetting and thought provoking , the film has an odd purity that does n't bring you into the characters so much as it has you study them
# ------------------------------------------------------------
# Example Index: 988, Predicted Label: -
# Review: it would n't matter so much that this arrogant richard pryor wannabe 's routine is offensive , puerile and unimaginatively foul mouthed if it was at least funny
# ------------------------------------------------------------
# Example Index: 989, Predicted Label: +
# Review: the film will appeal to discovery channel fans and will surely widen the perspective of those of us who see the continent through rose colored glasses
# ------------------------------------------------------------
# Example Index: 990, Predicted Label: -
# Review: a distinctly mixed bag , the occasional bursts of sharp writing alternating with lots of sloppiness and the obligatory moments of sentimental ooze
# ------------------------------------------------------------
# Example Index: 991, Predicted Label: +
# Review: it 's never laugh out loud funny , but it is frequently amusing
# ------------------------------------------------------------
# Example Index: 992, Predicted Label: +
# Review: adam sandler ! in an art film !
# ------------------------------------------------------------
# Example Index: 993, Predicted Label: -
# Review: the entire movie is in need of a scented bath
# ------------------------------------------------------------
# Example Index: 994, Predicted Label: -
# Review: makes 98 minutes feel like three hours
# ------------------------------------------------------------
# Example Index: 995, Predicted Label: +
# Review: has the rare capability to soothe and break your heart with a single stroke
# ------------------------------------------------------------
# Example Index: 996, Predicted Label: -
# Review: hawke 's film , a boring , pretentious waste of nearly two hours , does n't tell you anything except that the chelsea hotel today is populated by whiny , pathetic , starving and untalented artistes
# ------------------------------------------------------------
# Example Index: 997, Predicted Label: -
# Review: the movie is so resolutely cobbled together out of older movies that it even uses a totally unnecessary prologue , just because it seems obligatory
# ------------------------------------------------------------
# Example Index: 998, Predicted Label: -
# Review: instead of trying to bust some blondes , diggs should be probing why a guy with his talent ended up in a movie this bad
# ------------------------------------------------------------
# Example Index: 999, Predicted Label: +
# Review: a mesmerizing cinematic poem from the first frame to the last
# ------------------------------------------------------------
# Accuracy on dev_data: 0.761
